# %%
import os

from langchain.chat_models import ChatOpenAI
from langchain.chains import GraphCypherQAChain
from langchain.graphs import Neo4jGraph

# %%
# Connect to local Neo4j instance
graph = Neo4jGraph(url="neo4j://localhost:7687", username="neo4j", password="test")
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/langchain/graphs/neo4j_graph.py in __init__(self, url, username, password, database)
#      62         try:
# ---> 63             self._driver.verify_connectivity()
#      64         except neo4j.exceptions.ServiceUnavailable:
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/driver.py in verify_connectivity(self, **config)
#     984             session_config = self._read_session_config(config)
# --> 985             self._get_server_info(session_config)
#     986
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/driver.py in _get_server_info(self, session_config)
#    1199         with self._session(session_config) as session:
# -> 1200             return session._get_server_info()
#    1201
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/session.py in _get_server_info(self)
#     174         assert not self._connection
# --> 175         self._connect(READ_ACCESS, liveness_check_timeout=0)
#     176         server_info = self._connection.server_info
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/session.py in _connect(self, access_mode, **acquire_kwargs)
#     132         try:
# --> 133             super()._connect(
#     134                 access_mode, auth=self._config.auth, **acquire_kwargs
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py in _connect(self, access_mode, auth, **acquire_kwargs)
#     160                 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 161                 self._pool.update_routing_table(
#     162                     database=self._config.database,
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     775                 # TODO: Test this state
# --> 776                 if self._update_routing_table_from(
#     777                     self.address, database=database,
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in _update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     721             ):
# --> 722                 new_routing_table = self.fetch_routing_table(
#     723                     address=address, acquisition_timeout=acquisition_timeout,
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     658         try:
# --> 659             new_routing_info = self.fetch_routing_info(
#     660                 address, database, imp_user, bookmarks, auth,
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     626             auth.force_auth = False
# --> 627         cx = self._acquire(address, auth, deadline, None)
#     628         try:
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in _acquire(self, address, auth, deadline, liveness_check_timeout)
#     314         log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 315         return connection_creator()
#     316
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in connection_creator()
#     166                 try:
# --> 167                     connection = self.opener(
#     168                         address, auth or self.pool_config.auth, deadline
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py in opener(addr, auth_manager, deadline)
#     558         def opener(addr, auth_manager, deadline):
# --> 559             return Bolt.open(
#     560                 addr, auth_manager=auth_manager, deadline=deadline,
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py in open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     488             try:
# --> 489                 connection.hello()
#     490             finally:
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py in hello(self, dehydration_hooks, hydration_hooks)
#     580         self.send_all()
# --> 581         self.fetch_all()
#     582         check_supported_server_product(self.server_info.agent)
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py in fetch_all(self)
#     864             while not response.complete:
# --> 865                 detail_delta, summary_delta = self.fetch_message()
#     866                 detail_count += detail_delta
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     850         )
# --> 851         res = self._process_message(tag, fields)
#     852         self.idle_since = perf_counter()
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py in _process_message(self, tag, fields)
#     375             try:
# --> 376                 response.on_failure(summary_metadata or {})
#     377             except (ServiceUnavailable, DatabaseUnavailable):
#
# ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     282         Util.callback(handler)
# --> 283         raise Neo4jError.hydrate(**metadata)
#     284
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3371318/3414645085.py in <module>
#       1 # Connect to local Neo4j instance
# ----> 2 graph = Neo4jGraph(url="neo4j://localhost:7687", username="neo4j", password="test")
#
# ~/.local/lib/python3.10/site-packages/langchain/graphs/neo4j_graph.py in __init__(self, url, username, password, database)
#      68             )
#      69         except neo4j.exceptions.AuthError:
# ---> 70             raise ValueError(
#      71                 "Could not connect to Neo4j database. "
#      72                 "Please ensure that the username and password are correct"
#
# ValueError: Could not connect to Neo4j database. Please ensure that the username and password are correct
